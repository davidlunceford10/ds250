# %%
import pandas as pd
import numpy as np
from lets_plot import *

LetsPlot.setup_html(isolated_frame=True)
df = pd.read_csv("https://github.com/byuidatascience/data4names/raw/master/data-raw/names_year/names_year.csv")

# %%
duh = (
  ggplot(df, aes(x="name", y="year")) + geom_point()
)

duh
# Out:
# <html lang="en">
#    <head>
#        <meta charset="UTF-8">
#        <style> html, body { margin: 0; padding: 0; } </style>
#        <script type="text/javascript" data-lets-plot-script="library" src="https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.8.2/js-package/distr/lets-plot.min.js"></script>
#    </head>
#    <body>
#           <div id="2FYBWO" ></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("2FYBWO");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# },
# "mapping":{
# "x":"name",
# "y":"year"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"name"
# },{
# "type":"int",
# "column":"year"
# },{
# "type":"float",
# "column":"AK"
# },{
# "type":"float",
# "column":"AL"
# },{
# "type":"float",
# "column":"AR"
# },{
# "type":"float",
# "column":"AZ"
# },{
# "type":"float",
# "column":"CA"
# },{
# "type":"float",
# "column":"CO"
# },{
# "type":"float",
# "column":"CT"
# },{
# "type":"float",
# "column":"DC"
# },{
# "type":"float",
# "column":"DE"
# },{
# "type":"float",
# "column":"FL"
# },{
# "type":"float",
# "column":"GA"
# },{
# "type":"float",
# "column":"HI"
# },{
# "type":"float",
# "column":"IA"
# },{
# "type":"float",
# "column":"ID"
# },{
# "type":"float",
# "column":"IL"
# },{
# "type":"float",
# "column":"IN"
# },{
# "type":"float",
# "column":"KS"
# },{
# "type":"float",
# "column":"KY"
# },{
# "type":"float",
# "column":"LA"
# },{
# "type":"float",
# "column":"MA"
# },{
# "type":"float",
# "column":"MD"
# },{
# "type":"float",
# "column":"ME"
# },{
# "type":"float",
# "column":"MI"
# },{
# "type":"float",
# "column":"MN"
# },{
# "type":"float",
# "column":"MO"
# },{
# "type":"float",
# "column":"MS"
# },{
# "type":"float",
# "column":"MT"
# },{
# "type":"float",
# "column":"NC"
# },{
# "type":"float",
# "column":"ND"
# },{
# "type":"float",
# "column":"NE"
# },{
# "type":"float",
# "column":"NH"
# },{
# "type":"float",
# "column":"NJ"
# },{
# "type":"float",
# "column":"NM"
# },{
# "type":"float",
# "column":"NV"
# },{
# "type":"float",
# "column":"NY"
# },{
# "type":"float",
# "column":"OH"
# },{
# "type":"float",
# "column":"OK"
# },{
# "type":"float",
# "column":"OR"
# },{
# "type":"float",
# "column":"PA"
# },{
# "type":"float",
# "column":"RI"
# },{
# "type":"float",
# "column":"SC"
# },{
# "type":"float",
# "column":"SD"
# },{
# "type":"float",
# "column":"TN"
# },{
# "type":"float",
# "column":"TX"
# },{
# "type":"float",
# "column":"UT"
# },{
# "type":"float",
# "column":"VA"
# },{
# "type":"float",
# "column":"VT"
# },{
# "type":"float",
# "column":"WA"
# },{
# "type":"float",
# "column":"WI"
# },{
# "type":"float",
# "column":"WV"
# },{
# "type":"float",
# "column":"WY"
# },{
# "type":"float",
# "column":"Total"
# }]
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# "name":["Aaden","Aaden","Aaden","Aadhya","Aadhya","Aaliyah","Aaliyah","Aaliyah","Aaliyah","Aaliyah","Aamir","Aamir","Aamir","Aamir","Aamir","Aamir","Aamir","Aanya","Aanya","Aanya","Aanya","Aanya","Aanya","Aanya","Aarav","Aarav","Aarav","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aaron","Aarush","Aarush","Aarush","Aarya","Aarya","Aarya","Aarya","Aaryan","Aaryan","Aaryan","Aaryan","Aaryan","Aaryan","Aayan","Aayan","Aayden","Aayden","Aayden","Aayush","Aayush","Aayush","Aayush","Aayush","Abagail","Abagail","Abagail","Abagail","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbey","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbie","Abbigail","Abbigail","Abbigail","Abbigail","Abbigail","Abbigail","Abbigail","Abbigale","Abbigale","Abbigale","Abbigale","Abbigale","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abby","Abbygail","Abbygail","Abbygail","Abbygail","Abbygail","Abbygail","Abbygail","Abbygail","Abdiel","Abdiel","Abdiel","Abdiel","Abdiel","Abdiel","Abdiel","Abdiel","Abdirahman","Abdirahman","Abdirahman","Abdirahman","Abdirahman","Abdirahman","Abdul","Abdul","Abdul","Abdul","Abdul","Abdullah","Abdullah","Abdullah","Abdullah","Abdullah","Abdullah","Abdullah","Abdullah","Abdullah","Abdullahi","Abdullahi","Abdulrahman","Abdulrahman","Abdulrahman","Abdulrahman","Abdulrahman","Abdulrahman","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abe","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abel","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abelardo","Abhinav","Abhinav","Abhinav","Abhinav","Abhinav","Abhinav","Abhinav","Abhinav","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigail","Abigale","Abigale","Abigale","Abigale","Abigale","Abigayle","Abigayle","Abigayle","Abigayle","Abigayle","Abigayle","Abigayle","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abner","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abraham","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abram","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abran","Abriana","Abriana","Abriana","Abriana","Abrianna","Abrianna","Abrianna","Abrianna","Abrianna","Abrianna","Abrianna","Abrianna","Abrianna","Abrielle","Abrielle","Abrielle","Abrielle","Abrielle","Abrielle","Abril","Abril","Abril","Abril","Abril","Abril","Abril","Abril","Abril","Abril","Abril","Abygail","Abygail","Abygail","Abygail","Abygail","Abygail","Abygail","Abygail","Abyg ...
